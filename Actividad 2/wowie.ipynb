# %% [markdown]
# # Mi primer proyecto de visión computacional
# Este proyecto es un ejemplo de cómo utilizar OpenCV de manera efectiva yahoo

# %%
# !pip install matplotlib

# %%
# Importar librerias
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
bgr = cv2.imread('vso.jpg')
print("El tamaño de la imagen es: ", bgr.shape)

# Convertir a RGB
rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(rgb)
# Out:
# El tamaño de la imagen es:  (426, 474, 3)

# %%
# Mostrar la imagen en escala de grises
gray = cv2.cvtColor(bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
# Mostrar los componentes de color de la imagen       
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.imshow(bgr[:,:,0], cmap='gray')
plt.title('Canal Azul')
plt.subplot(1, 3, 2)
plt.imshow(bgr[:,:,1], cmap='gray')
plt.title('Canal Verde')
plt.subplot(1, 3, 3)
plt.imshow(bgr[:,:,2], cmap='gray')
plt.title('Canal Rojo')
# Out:
# Text(0.5, 1.0, 'Canal Rojo')

# %%
# Mostrar los componentes HLS de la imagen
hls = cv2.cvtColor(bgr, cv2.COLOR_BGR2HLS)
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.imshow(hls[:,:,0], cmap='gray')
plt.title('Canal de Matiz')
plt.subplot(1, 3, 2)
plt.imshow(hls[:,:,1], cmap='gray')
plt.title('Canal de Saturación')
plt.subplot(1, 3, 3)
plt.imshow(hls[:,:,2], cmap='gray')
plt.title('Canal de Luminosidad')
plt.show()
